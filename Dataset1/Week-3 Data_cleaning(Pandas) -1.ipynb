# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the csvfile
data =pd.read_csv("Week3_Data.csv")

# %%
#pritning the 1st 5 data
data.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
#creating the dataframe for the data
df=pd.DataFrame(data)
df.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
#removing the Index Column
df.drop('Index',axis=1,inplace=True)
df
# Out:
#      Age      Salary  Rating       Location  Established Easy Apply
# 0   44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1   66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2    NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3   64.0   $44k-$99k     4.4       India In         1988         -1
# 4   25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5   44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6   21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7   44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8   35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9   22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# 11  44.0   $10k-$49k     6.7       India,In         2009         -1
# 12   NaN   $44k-$99k     0.0       India,In         1999         -1
# 13  25.0   $44k-$99k    -1.0  Australia Aus         2019       TRUE
# 14  66.0   $44k-$99k     4.0  Australia Aus         2020       TRUE
# 15  44.0  $88k-$101k     3.0  Australia Aus         1999         -1
# 16  19.0   $19k-$40k     4.5       India,In         1984         -1
# 17   NaN   $44k-$99k     5.3    New York,Ny         1943       TRUE
# 18  35.0   $44k-$99k     6.7    New York,Ny         1954       TRUE
# 19  32.0   $44k-$99k     3.3    New York,Ny         1955       TRUE
# 20   NaN   $44k-$99k     5.7    New York,Ny         1944       TRUE
# 21  35.0   $44k-$99k     5.0    New York,Ny         1946         -1
# 22  19.0   $55k-$66k     7.8    New York,Ny         1988       TRUE
# 23   NaN   $44k-$99k     2.4    New York,Ny         1999       TRUE
# 24  13.0   $44k-$99k    -1.0    New York,Ny         1987         -1
# 25  55.0   $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26   NaN   $55k-$66k     NaN       India,In         1934       TRUE
# 27  52.0   $44k-$99k     5.4       India,In         1935         -1
# 28   NaN   $39k-$88k     3.4  Australia Aus         1932         -1

# %% [markdown]
# # 1. Missing Values:
# Question: Are there any missing values in the dataset, and if so, how should they be handled for each indicator?

# %%
df.isnull()
df.isnull().sum()
# Out:
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
df.head()
# Out:
#     Age     Salary  Rating       Location  Established Easy Apply
# 0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
df
# Out:
#      Age      Salary  Rating       Location  Established Easy Apply
# 0   44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1   66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2    NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3   64.0   $44k-$99k     4.4       India In         1988         -1
# 4   25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5   44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6   21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7   44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8   35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9   22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# 11  44.0   $10k-$49k     6.7       India,In         2009         -1
# 12   NaN   $44k-$99k     0.0       India,In         1999         -1
# 13  25.0   $44k-$99k    -1.0  Australia Aus         2019       TRUE
# 14  66.0   $44k-$99k     4.0  Australia Aus         2020       TRUE
# 15  44.0  $88k-$101k     3.0  Australia Aus         1999         -1
# 16  19.0   $19k-$40k     4.5       India,In         1984         -1
# 17   NaN   $44k-$99k     5.3    New York,Ny         1943       TRUE
# 18  35.0   $44k-$99k     6.7    New York,Ny         1954       TRUE
# 19  32.0   $44k-$99k     3.3    New York,Ny         1955       TRUE
# 20   NaN   $44k-$99k     5.7    New York,Ny         1944       TRUE
# 21  35.0   $44k-$99k     5.0    New York,Ny         1946         -1
# 22  19.0   $55k-$66k     7.8    New York,Ny         1988       TRUE
# 23   NaN   $44k-$99k     2.4    New York,Ny         1999       TRUE
# 24  13.0   $44k-$99k    -1.0    New York,Ny         1987         -1
# 25  55.0   $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26   NaN   $55k-$66k     NaN       India,In         1934       TRUE
# 27  52.0   $44k-$99k     5.4       India,In         1935         -1
# 28   NaN   $39k-$88k     3.4  Australia Aus         1932         -1

# %%
#Missing values of Age column is filled by the Mean value
mean_age=df['Age'].mean()
df['Age'].fillna(mean_age,inplace=True)
df
# Out:
#           Age      Salary  Rating       Location  Established Easy Apply
# 0   44.000000   $44k-$99k     5.4       India,In         1999       TRUE
# 1   66.000000   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2   39.045455   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3   64.000000   $44k-$99k     4.4       India In         1988         -1
# 4   25.000000   $44k-$99k     6.4  Australia Aus         2002         -1
# 5   44.000000   $77k-$89k     1.4       India,In         1999       TRUE
# 6   21.000000   $44k-$99k     0.0    New York,Ny           -1         -1
# 7   44.000000   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8   35.000000   $44k-$99k     5.4    New York,Ny           -1         -1
# 9   22.000000   $44k-$99k     7.7       India,In           -1       TRUE
# 10  55.000000   $10k-$49k     5.4       India,In         2008       TRUE
# 11  44.000000   $10k-$49k     6.7       India,In         2009         -1
# 12  39.045455   $44k-$99k     0.0       India,In         1999         -1
# 13  25.000000   $44k-$99k    -1.0  Australia Aus         2019       TRUE
# 14  66.000000   $44k-$99k     4.0  Australia Aus         2020       TRUE
# 15  44.000000  $88k-$101k     3.0  Australia Aus         1999         -1
# 16  19.000000   $19k-$40k     4.5       India,In         1984         -1
# 17  39.045455   $44k-$99k     5.3    New York,Ny         1943       TRUE
# 18  35.000000   $44k-$99k     6.7    New York,Ny         1954       TRUE
# 19  32.000000   $44k-$99k     3.3    New York,Ny         1955       TRUE
# 20  39.045455   $44k-$99k     5.7    New York,Ny         1944       TRUE
# 21  35.000000   $44k-$99k     5.0    New York,Ny         1946         -1
# 22  19.000000   $55k-$66k     7.8    New York,Ny         1988       TRUE
# 23  39.045455   $44k-$99k     2.4    New York,Ny         1999       TRUE
# 24  13.000000   $44k-$99k    -1.0    New York,Ny         1987         -1
# 25  55.000000   $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26  39.045455   $55k-$66k     NaN       India,In         1934       TRUE
# 27  52.000000   $44k-$99k     5.4       India,In         1935         -1
# 28  39.045455   $39k-$88k     3.4  Australia Aus         1932         -1

# %%
df['Age']=df['Age'].astype(int) #converting the age column to int data type
df['Age'].tail()
# Out:
# 24    13
# 25    55
# 26    39
# 27    52
# 28    39
# Name: Age, dtype: int32

# %% [markdown]
# Rating column has one missing value and is
# handled by using 'ffill' or 'bfill' method or fillna with 0

# %%
df['Rating']=df['Rating'].fillna(method='ffill')
df['Rating'].head()
# Out:
# 0    5.4
# 1    3.5
# 2   -1.0
# 3    4.4
# 4    6.4
# Name: Rating, dtype: float64

# %% [markdown]
# # 2. Data Types:
# Question: What are the data types of each indicator, and do they align with their expected types (e.g., numerical, categorical)?

# %%
df.dtypes
# Out:
# Age              int32
# Salary          object
# Rating         float64
# Location        object
# Established      int64
# Easy Apply      object
# dtype: object

# %%
df['Location']=df['Location'].astype('category')
df.dtypes
# Out:
# Age               int32
# Salary           object
# Rating          float64
# Location       category
# Established       int64
# Easy Apply       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          29 non-null     int32
#  1   Salary       29 non-null     object
#  2   Rating       29 non-null     float64
#  3   Location     29 non-null     category
#  4   Established  29 non-null     int64
#  5   Easy Apply   29 non-null     object
# dtypes: category(1), float64(1), int32(1), int64(1), object(2)
# memory usage: 1.4+ KB

# %% [markdown]
# # 4. Salary Formatting:
# Question: Examine the format of the Salary column. Does it require any formatting or standardization for consistent analysis?

# %%
df['Salary'].head()
# Out:
# 0    $44k-$99k
# 1    $55k-$66k
# 2    $77k-$89k
# 3    $44k-$99k
# 4    $44k-$99k
# Name: Salary, dtype: object

# %%
# Removing $ symbols and 'k', split ranges, and converting to numeric values

# %%
df['Salary'] = df['Salary'].str.replace(r'[\$\,]', '', regex=True)  # Remove symbols
df[['Min Salary', 'Max Salary']] = df['Salary'].str.split('-', expand=True)  # Split range into two columns
df[['Min Salary', 'Max Salary']] = df[['Min Salary', 'Max Salary']].replace('k', '', regex=True).astype(int) * 1000  # Convert 'k' to numeric and multiply by 1000

# Calculate average salary
df['Average Salary'] = (df['Min Salary'] + df['Max Salary']) / 2

# %%
# Removing symbols
df['Salary'] = df['Salary'].str.replace(r'[\$]', '', regex=True) 
df['Salary'].head()
# Out:
# 0    44k-99k
# 1    55k-66k
# 2    77k-89k
# 3    44k-99k
# 4    44k-99k
# Name: Salary, dtype: object

# %%
# Splitting range into two columns
df[['Min Salary', 'Max Salary']] = df['Salary'].str.split('-', expand=True)
df[['Min Salary','Max Salary']].head()
# Out:
#   Min Salary Max Salary
# 0        44k        99k
# 1        55k        66k
# 2        77k        89k
# 3        44k        99k
# 4        44k        99k

# %%
# Converting 'k' to numeric and multiply by 1000
df[['Min Salary', 'Max Salary']] = df[['Min Salary', 'Max Salary']].replace('k', '', regex=True).astype(int) * 1000
df[['Min Salary', 'Max Salary']].head()
# Out:
#    Min Salary  Max Salary
# 0       44000       99000
# 1       55000       66000
# 2       77000       89000
# 3       44000       99000
# 4       44000       99000

# %%
# Calculating average salary
df['Average Salary'] = (df['Min Salary'] + df['Max Salary']) / 2

# %%
# Replacing 'Salary' column with 'Average Salary' and renaming it
df['Average Salary'].head()
# Out:
# 0    71500.0
# 1    60500.0
# 2    83000.0
# 3    71500.0
# 4    71500.0
# Name: Average Salary, dtype: float64

# %%
#Dropping the columns (min salary,max salary,salary)
df = df.drop(columns=['Min Salary', 'Max Salary', 'Salary'])

# %%
df.head()
# Out:
#    Age  Rating       Location  Established Easy Apply  Average Salary
# 0   44     5.4       India,In         1999       TRUE         71500.0
# 1   66     3.5    New York,Ny         2002       TRUE         60500.0
# 2   39    -1.0    New York,Ny           -1         -1         83000.0
# 3   64     4.4       India In         1988         -1         71500.0
# 4   25     6.4  Australia Aus         2002         -1         71500.0

# %% [markdown]
# # 3. Outliers:
# Question: Identify potential outliers in numerical indicators (e.g., Age, Salary, Rating). Should outliers be removed or adjusted?

# %%
df.describe()
# Out:
#              Age     Rating  Established  Average Salary
# count  29.000000  29.000000    29.000000       29.000000
# mean   39.034483   3.406897  1638.620690    67327.586207
# std    13.973145   2.850555   762.079599    14647.815453
# min    13.000000  -1.000000    -1.000000    29500.000000
# 25%    32.000000   0.000000  1935.000000    71500.000000
# 50%    39.000000   4.000000  1984.000000    71500.000000
# 75%    44.000000   5.400000  1999.000000    71500.000000
# max    66.000000   7.800000  2020.000000    94500.000000

# %%
sns.distplot(df['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # Detecting Outliers using IQR method (for Age Column)

# %%
q1=df['Age'].quantile(0.25)
q3=df['Age'].quantile(0.75)
iqr=q3-q1

# %%
print("q1:",q1)
print("q3:",q3)
print("IQR:",iqr)
# Out:
# q1: 32.0
# q3: 44.0
# IQR: 12.0

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)

# %%
print(upper_limit)
print(lower_limit)
# Out:
# 62.0
# 14.0

# %%
#Finding the outliers
df.loc[(df['Age'] > upper_limit) | (df['Age'] < lower_limit)]
# Out:
#     Age  Rating       Location  Established Easy Apply  Average Salary
# 1    66     3.5    New York,Ny         2002       TRUE         60500.0
# 3    64     4.4       India In         1988         -1         71500.0
# 14   66     4.0  Australia Aus         2020       TRUE         71500.0
# 24   13    -1.0    New York,Ny         1987         -1         71500.0

# %%
#trimming the data
new_df=df.loc[(df['Age'] < upper_limit) & (df['Age'] > lower_limit)]
print("Before removing the outliers:",len(df))
print("After removing the outliers:",len(new_df))
print("Outliers:",len(df)-len(new_df))
# Out:
# Before removing the outliers: 29
# After removing the outliers: 25
# Outliers: 4

# %%
sns.boxplot(new_df['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
#capping -changing the outlier values to upper limit(62) and lower limit(14)
new_df=df.copy()
new_df.loc[(new_df['Age'] > upper_limit),'Age'] = upper_limit
new_df.loc[new_df['Age'] < lower_limit,'Age']=lower_limit
df['Age']=new_df['Age']
df
# Out:
#     Age  Rating       Location  Established Easy Apply  Average Salary
# 0    44     5.4       India,In         1999       TRUE         71500.0
# 1    62     3.5    New York,Ny         2002       TRUE         60500.0
# 2    39    -1.0    New York,Ny           -1         -1         83000.0
# 3    62     4.4       India In         1988         -1         71500.0
# 4    25     6.4  Australia Aus         2002         -1         71500.0
# 5    44     1.4       India,In         1999       TRUE         83000.0
# 6    21     0.0    New York,Ny           -1         -1         71500.0
# 7    44    -1.0  Australia Aus           -1         -1         71500.0
# 8    35     5.4    New York,Ny           -1         -1         71500.0
# 9    22     7.7       India,In           -1       TRUE         71500.0
# 10   55     5.4       India,In         2008       TRUE         29500.0
# 11   44     6.7       India,In         2009         -1         29500.0
# 12   39     0.0       India,In         1999         -1         71500.0
# 13   25    -1.0  Australia Aus         2019       TRUE         71500.0
# 14   62     4.0  Australia Aus         2020       TRUE         71500.0
# 15   44     3.0  Australia Aus         1999         -1         94500.0
# 16   19     4.5       India,In         1984         -1         29500.0
# 17   39     5.3    New York,Ny         1943       TRUE         71500.0
# 18   35     6.7    New York,Ny         1954       TRUE         71500.0
# 19   32     3.3    New York,Ny         1955       TRUE         71500.0
# 20   39     5.7    New York,Ny         1944       TRUE         71500.0
# 21   35     5.0    New York,Ny         1946         -1         71500.0
# 22   19     7.8    New York,Ny         1988       TRUE         60500.0
# 23   39     2.4    New York,Ny         1999       TRUE         71500.0
# 24   14    -1.0    New York,Ny         1987         -1         71500.0
# 25   55     0.0  Australia Aus         1980       TRUE         71500.0
# 26   39     0.0       India,In         1934       TRUE         60500.0
# 27   52     5.4       India,In         1935         -1         71500.0
# 28   39     3.4  Australia Aus         1932         -1         63500.0

# %% [markdown]
# # Detecting Outliers for rating -using Z-Score method

# %%
upper_limit=df['Rating'].mean()+3*df['Rating'].std()
lower_limit=df['Rating'].mean()-3*df['Rating'].std()
print('upper_limit:',upper_limit)
print('lower_limit:',lower_limit)
# Out:
# upper_limit: 11.958562191918151
# lower_limit: -5.144769088469875

# %%
sns.boxplot(df['Rating'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating'>

# %%
#finding the outliers 
df.loc[(df['Rating'] > upper_limit) | (df['Rating'] < lower_limit)] #no outliers found
# Out:
# Empty DataFrame
# Columns: [Age, Rating, Location, Established, Easy Apply, Average Salary]
# Index: []

# %% [markdown]
# # Detecting the outliers for Salary -using Percentile method

# %% [markdown]
# The data less than 1%(0.01) and more than 99%(0.99) will be considered as outliers

# %%
upper_limit=df['Average Salary'].quantile(0.99)
lower_limit=df['Average Salary'].quantile(0.01)
print(upper_limit)
print(lower_limit)
# Out:
# 91279.99999999999
# 29500.0

# %%
#finding the outliers
df.loc[(df['Average Salary'] > upper_limit) | (df['Average Salary'] < lower_limit)]
# Out:
#     Age  Rating       Location  Established Easy Apply  Average Salary
# 15   44     3.0  Australia Aus         1999         -1         94500.0

# %%
 #trimming -deleting the outlier data
new_df1=df.loc[(df['Average Salary'] <= upper_limit) & (df['Average Salary'] >= lower_limit)]
print("Before removing outliers:",len(df))
print("After removing outliers:",len(new_df1))
print("outliers:",len(df)-len(new_df1))
# Out:
# Before removing outliers: 29
# After removing outliers: 28
# outliers: 1

# %%
#capping -changing the outlier values to upper limit(91278)
new_df=df.copy()
new_df.loc[(new_df['Average Salary'] > upper_limit),'Average Salary'] = upper_limit
new_df
# Out:
#     Age  Rating       Location  Established Easy Apply  Average Salary
# 0    44     5.4       India,In         1999       TRUE         71500.0
# 1    62     3.5    New York,Ny         2002       TRUE         60500.0
# 2    39    -1.0    New York,Ny           -1         -1         83000.0
# 3    62     4.4       India In         1988         -1         71500.0
# 4    25     6.4  Australia Aus         2002         -1         71500.0
# 5    44     1.4       India,In         1999       TRUE         83000.0
# 6    21     0.0    New York,Ny           -1         -1         71500.0
# 7    44    -1.0  Australia Aus           -1         -1         71500.0
# 8    35     5.4    New York,Ny           -1         -1         71500.0
# 9    22     7.7       India,In           -1       TRUE         71500.0
# 10   55     5.4       India,In         2008       TRUE         29500.0
# 11   44     6.7       India,In         2009         -1         29500.0
# 12   39     0.0       India,In         1999         -1         71500.0
# 13   25    -1.0  Australia Aus         2019       TRUE         71500.0
# 14   62     4.0  Australia Aus         2020       TRUE         71500.0
# 15   44     3.0  Australia Aus         1999         -1         91280.0
# 16   19     4.5       India,In         1984         -1         29500.0
# 17   39     5.3    New York,Ny         1943       TRUE         71500.0
# 18   35     6.7    New York,Ny         1954       TRUE         71500.0
# 19   32     3.3    New York,Ny         1955       TRUE         71500.0
# 20   39     5.7    New York,Ny         1944       TRUE         71500.0
# 21   35     5.0    New York,Ny         1946         -1         71500.0
# 22   19     7.8    New York,Ny         1988       TRUE         60500.0
# 23   39     2.4    New York,Ny         1999       TRUE         71500.0
# 24   14    -1.0    New York,Ny         1987         -1         71500.0
# 25   55     0.0  Australia Aus         1980       TRUE         71500.0
# 26   39     0.0       India,In         1934       TRUE         60500.0
# 27   52     5.4       India,In         1935         -1         71500.0
# 28   39     3.4  Australia Aus         1932         -1         63500.0

# %% [markdown]
# # 5. Location Standardization: & 10.Handling Special characters
# Question: Check the consistency of location entries. Do they need standardization, and how can this be achieved?

# %%
df['Location']
# Out:
# 0          India,In
# 1       New York,Ny
# 2       New York,Ny
# 3          India In
# 4     Australia Aus
# 5          India,In
# 6       New York,Ny
# 7     Australia Aus
# 8       New York,Ny
# 9          India,In
# 10         India,In
# 11         India,In
# 12         India,In
# 13    Australia Aus
# 14    Australia Aus
# 15    Australia Aus
# 16         India,In
# 17      New York,Ny
# 18      New York,Ny
# 19      New York,Ny
# 20      New York,Ny
# 21      New York,Ny
# 22      New York,Ny
# 23      New York,Ny
# 24      New York,Ny
# 25    Australia Aus
# 26         India,In
# 27         India,In
# 28    Australia Aus
# Name: Location, dtype: category
# Categories (4, object): ['Australia Aus', 'India In', 'India,In', 'New York,Ny']

# %% [markdown]
# cleaning and standarization of the Location column- using Regex

# %%
df['Location'] = df['Location'].str.replace(r',.*', '', regex=True)  # Removing everything after comma
df['Location'] = df['Location'].str.replace(r'[^a-zA-Z\s]', '')     # Removing non-alphabetic and non-space characters
# Out:
# C:\Users\91638\AppData\Local\Temp\ipykernel_264\3028845961.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Location'] = df['Location'].str.replace(r'[^a-zA-Z\s]', '')     # Removing non-alphabetic and non-space characters

# %%
# Additional cleaning for 'India In'
df['Location'] = df['Location'].str.replace(r'\sIn$', '')            # Remove ' In' at the end of entries
# Out:
# C:\Users\91638\AppData\Local\Temp\ipykernel_264\3210236826.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Location'] = df['Location'].str.replace(r'\sIn$', '')            # Remove ' In' at the end of entries

# %%
#Additional cleaning for 'Australia Aus'
df['Location'] = df['Location'].str.replace(r'\sAus$', '')           # Remove ' Aus' at the end of entries
# Out:
# C:\Users\91638\AppData\Local\Temp\ipykernel_264\1513091158.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Location'] = df['Location'].str.replace(r'\sAus$', '')           # Remove ' Aus' at the end of entries

# %%
df['Location']
# Out:
# 0         India
# 1      New York
# 2      New York
# 3         India
# 4     Australia
# 5         India
# 6      New York
# 7     Australia
# 8      New York
# 9         India
# 10        India
# 11        India
# 12        India
# 13    Australia
# 14    Australia
# 15    Australia
# 16        India
# 17     New York
# 18     New York
# 19     New York
# 20     New York
# 21     New York
# 22     New York
# 23     New York
# 24     New York
# 25    Australia
# 26        India
# 27        India
# 28    Australia
# Name: Location, dtype: object

# %% [markdown]
# standarizing the Location column by defining it in a dictionary

# %% [markdown]
# # 6. Established Column:
# Question: Explore the Established column. Are there any inconsistencies or anomalies that need to be addressed?

# %%
df['Established'].head(11)
# Out:
# 0     1999
# 1     2002
# 2       -1
# 3     1988
# 4     2002
# 5     1999
# 6       -1
# 7       -1
# 8       -1
# 9       -1
# 10    2008
# Name: Established, dtype: int64

# %% [markdown]
# Replacing -1 with the median establishment year based on the location

# %%
#Replacing '-1' with median establishment year per Location
median_per_location=df[df['Established']!=-1].groupby('Location')['Established'].median().astype(int)

# %%
df['Established'] = df.apply(lambda row: median_per_location[row['Location']] if row['Established'] == -1 else row['Established'], axis=1)
df.head(11)
# Out:
#     Age  Rating   Location  Established Easy Apply  Average Salary
# 0    44     5.4      India         1999       TRUE         71500.0
# 1    62     3.5   New York         2002       TRUE         60500.0
# 2    39    -1.0   New York         1955         -1         83000.0
# 3    62     4.4      India         1988         -1         71500.0
# 4    25     6.4  Australia         2002         -1         71500.0
# 5    44     1.4      India         1999       TRUE         83000.0
# 6    21     0.0   New York         1955         -1         71500.0
# 7    44    -1.0  Australia         2000         -1         71500.0
# 8    35     5.4   New York         1955         -1         71500.0
# 9    22     7.7      India         1999       TRUE         71500.0
# 10   55     5.4      India         2008       TRUE         29500.0

# %% [markdown]
# # 7. Easy Apply Indicator & 12. Easy Apply Transformation:
#
# Question: Analyze the Easy Apply column. Does it contain boolean values or need transformation for better analysis?

# %%
df['Easy Apply']
# Out:
# 0     TRUE
# 1     TRUE
# 2       -1
# 3       -1
# 4       -1
# 5     TRUE
# 6       -1
# 7       -1
# 8       -1
# 9     TRUE
# 10    TRUE
# 11      -1
# 12      -1
# 13    TRUE
# 14    TRUE
# 15      -1
# 16      -1
# 17    TRUE
# 18    TRUE
# 19    TRUE
# 20    TRUE
# 21      -1
# 22    TRUE
# 23    TRUE
# 24      -1
# 25    TRUE
# 26    TRUE
# 27      -1
# 28      -1
# Name: Easy Apply, dtype: object

# %%
# counting the true and missing values

count_true=df[df['Easy Apply'] == 'TRUE']['Easy Apply'].count()
count_missing=df[df['Easy Apply']== '-1']['Easy Apply'].count()

print("Count of TRUE :",count_true)
print("Count of -1 entries :",count_missing)
# Out:
# Count of TRUE : 15
# Count of -1 entries : 14

# %%
# Converting 'Easy Apply' to boolean (assuming -1 represents Flase)
df['Easy Apply'] = df['Easy Apply'].replace({'TRUE': True, '-1': False, }).astype('bool')

# %%
df.head()
# Out:
#    Age  Rating   Location  Established  Easy Apply  Average Salary
# 0   44     5.4      India         1999        True         71500.0
# 1   62     3.5   New York         2002        True         60500.0
# 2   39    -1.0   New York         1955       False         83000.0
# 3   62     4.4      India         1988       False         71500.0
# 4   25     6.4  Australia         2002       False         71500.0

# %%
#Verifying if the data type of the 'Easy Apply' column is boolean
df.dtypes
# Out:
# Age                 int32
# Rating            float64
# Location           object
# Established         int64
# Easy Apply           bool
# Average Salary    float64
# dtype: object

# %% [markdown]
# # 8. Rating Range:
# Question: Investigate the range of values in the Rating column. Does it fall within expected rating scales, and how should outliers be treated?

# %%
df['Rating']
# Out:
# 0     5.4
# 1     3.5
# 2    -1.0
# 3     4.4
# 4     6.4
# 5     1.4
# 6     0.0
# 7    -1.0
# 8     5.4
# 9     7.7
# 10    5.4
# 11    6.7
# 12    0.0
# 13   -1.0
# 14    4.0
# 15    3.0
# 16    4.5
# 17    5.3
# 18    6.7
# 19    3.3
# 20    5.7
# 21    5.0
# 22    7.8
# 23    2.4
# 24   -1.0
# 25    0.0
# 26    0.0
# 27    5.4
# 28    3.4
# Name: Rating, dtype: float64

# %%
#Investigating the range of values
print("Range of values in 'Rating' column:")
print(df['Rating'].describe())
# Out:
# Range of values in 'Rating' column:
# count    29.000000
# mean      3.406897
# std       2.850555
# min      -1.000000
# 25%       0.000000
# 50%       4.000000
# 75%       5.400000
# max       7.800000
# Name: Rating, dtype: float64

# %%
#Assuming the range to be (0 to 5)
lower_bound=0
upper_bound=5

# %%
# Counting values less than lower bound
count_lower = (df['Rating'] < lower_bound).sum()
print('count_lower',count_lower)
# Counting values greater than upper bound
count_upper = (df['Rating'] > upper_bound).sum()
print('count_upper',count_upper)
# Out:
# count_lower 4
# count_upper 11

# %%
# Replacing the  outliers with lower/upper bounds using clip method
new_df=df.copy()
new_df['Rating'] = df['Rating'].clip(lower=lower_bound, upper=upper_bound)
df['Rating'] = new_df['Rating']

# %%
#Verifying if the ouliers has been capped
count_lower = (new_df['Rating'] < lower_bound).sum()
print('count_lower',count_lower)
count_upper = (new_df['Rating'] > upper_bound).sum()
print('count_upper',count_upper)
# Out:
# count_lower 0
# count_upper 0

# %%
df.head(10)
# Out:
#    Age  Rating   Location  Established  Easy Apply  Average Salary
# 0   44     5.0      India         1999        True         71500.0
# 1   62     3.5   New York         2002        True         60500.0
# 2   39     0.0   New York         1955       False         83000.0
# 3   62     4.4      India         1988       False         71500.0
# 4   25     5.0  Australia         2002       False         71500.0
# 5   44     1.4      India         1999        True         83000.0
# 6   21     0.0   New York         1955       False         71500.0
# 7   44     0.0  Australia         2000       False         71500.0
# 8   35     5.0   New York         1955       False         71500.0
# 9   22     5.0      India         1999        True         71500.0

# %% [markdown]
# # 9. Age Distribution:
# Question: Check the distribution of values in the Age column. Are there any unusual entries, and how might they impact analysis?

# %%
# Descriptive statistics for 'Age'
age_stats = df['Age'].describe()
print("Descriptive Statistics for Age:")
print(age_stats)
# Out:
# Descriptive Statistics for Age:
# count    29.000000
# mean     38.724138
# std      13.252753
# min      14.000000
# 25%      32.000000
# 50%      39.000000
# 75%      44.000000
# max      62.000000
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt

# Histogram for 'Age'
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=10, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
# Boxplot for 'Age'
plt.figure(figsize=(8, 6))
plt.boxplot(df['Age'])
plt.ylabel('Age')
plt.title('Age Distribution')
plt.show()

# %%
# Defining thresholds for unusual ages (e.g., outside the range 18-65)
lower_threshold = 18
upper_threshold = 65

# Filtering  for ages outside the defined thresholds
unusual_ages = df[(df['Age'] < lower_threshold) | (df['Age'] > upper_threshold)]
print("Unusual Entries for Age:")
print(unusual_ages)
# Out:
# Unusual Entries for Age:
#     Age  Rating  Location  Established  Easy Apply  Average Salary
# 24   14     0.0  New York         1987       False         71500.0

# %%
#Before removing the data with the age=14
df['Age'].count().sum()
# Out:
# 29

# %%
#Removing the data with the age=14
df = df[df['Age'] != 14]

# %%
#count After removing the data with age 14
df['Age'].count().sum()
# Out:
# 28

# %% [markdown]
# Due to contextual considerations, entries with an age of 14 have been excluded from the analysis. This decision was made based on the assumption that individuals at this age might not typically meet the criteria for 'Easy Apply' positions and higher salaries, which could impact the accuracy of the analysis within the specified context.

# %%
df
# Out:
#     Age  Rating   Location  Established  Easy Apply  Average Salary
# 0    44     5.0      India         1999        True         71500.0
# 1    62     3.5   New York         2002        True         60500.0
# 2    39     0.0   New York         1955       False         83000.0
# 3    62     4.4      India         1988       False         71500.0
# 4    25     5.0  Australia         2002       False         71500.0
# 5    44     1.4      India         1999        True         83000.0
# 6    21     0.0   New York         1955       False         71500.0
# 7    44     0.0  Australia         2000       False         71500.0
# 8    35     5.0   New York         1955       False         71500.0
# 9    22     5.0      India         1999        True         71500.0
# 10   55     5.0      India         2008        True         29500.0
# 11   44     5.0      India         2009       False         29500.0
# 12   39     0.0      India         1999       False         71500.0
# 13   25     0.0  Australia         2019        True         71500.0
# 14   62     4.0  Australia         2020        True         71500.0
# 15   44     3.0  Australia         1999       False         94500.0
# 16   19     4.5      India         1984       False         29500.0
# 17   39     5.0   New York         1943        True         71500.0
# 18   35     5.0   New York         1954        True         71500.0
# 19   32     3.3   New York         1955        True         71500.0
# 20   39     5.0   New York         1944        True         71500.0
# 21   35     5.0   New York         1946       False         71500.0
# 22   19     5.0   New York         1988        True         60500.0
# 23   39     2.4   New York         1999        True         71500.0
# 25   55     0.0  Australia         1980        True         71500.0
# 26   39     0.0      India         1934        True         60500.0
# 27   52     5.0      India         1935       False         71500.0
# 28   39     3.4  Australia         1932       False         63500.0

# %% [markdown]
# # 11. Data Integrity:
# Question: Ensure data integrity by cross-referencing entries. For instance, does the Established column align with the Age column?

# %% [markdown]
# # Cross-Reference 'Established' with 'Age':

# %%
import datetime as dt

# %%
# Calculating current year
current_year = dt.datetime.now().year
current_year
# Out:
# 2023

# %%
# Calculating expected ages based on the provided integer year of establishment
df['Expected_Age'] = current_year - df['Established']
# Out:
# C:\Users\91638\AppData\Local\Temp\ipykernel_264\889060897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Expected_Age'] = current_year - df['Established']

# %%
# Identifying discrepancies between Expected Age and Provided Age
discrepancies = df[df['Expected_Age'] != df['Age']]

# %%
# Displaying  only 'Age' and 'Expected_Age' columns where Expected Age and Provided Age don't align
print("Entries where Expected Age and Provided Age don't align:")
print(discrepancies[['Age', 'Expected_Age']])
# Out:
# Entries where Expected Age and Provided Age don't align:
#     Age  Expected_Age
# 0    44            24
# 1    62            21
# 2    39            68
# 3    62            35
# 4    25            21
# 5    44            24
# 6    21            68
# 7    44            23
# 8    35            68
# 9    22            24
# 10   55            15
# 11   44            14
# 12   39            24
# 13   25             4
# 14   62             3
# 15   44            24
# 16   19            39
# 17   39            80
# 18   35            69
# 19   32            68
# 20   39            79
# 21   35            77
# 22   19            35
# 23   39            24
# 25   55            43
# 26   39            89
# 27   52            88
# 28   39            91

# %% [markdown]
# # Cross-Reference the 'Location' and 'Established'

# %%
# Group by Location and check the Established years for each location
location_established = df.groupby('Location')['Established'].unique()

# %%
location_established
# Out:
# Location
# Australia          [2002, 2000, 2019, 2020, 1999, 1980, 1932]
# India              [1999, 1988, 2008, 2009, 1984, 1934, 1935]
# New York     [2002, 1955, 1943, 1954, 1944, 1946, 1988, 1999]
# Name: Established, dtype: object

# %% [markdown]
# The dataset includes entities from these locations with diverse establishment years. The range of establishment years within each location indicates a mix of both older and more recent entities, providing a varied temporal perspective of the establishments from these specific regions.

# %% [markdown]
# # Cross-reference 'Location' with 'Rating'

# %%
# Calculating average rating per location
avg_rating_per_location = df.groupby('Location')['Rating'].mean().sort_values(ascending=False)

# Displaying  average ratings per location
print("Average ratings per location:")
print(avg_rating_per_location)
# Out:
# Average ratings per location:
# Location
# New York     3.563636
# India        3.530000
# Australia    2.200000
# Name: Rating, dtype: float64

# %% [markdown]
# # 13. Location Accuracy:
# Question: Assess the accuracy of location entries. Are there misspelled or ambiguous locations that require correction?

# %%
# Getting the  unique locations
unique_locations = df['Location'].unique()

# Sorting and printing unique locations for inspection
unique_locations_sorted = sorted(unique_locations)
for location in unique_locations_sorted:
    print(location)
# Out:
# Australia
# India
# New York

# %% [markdown]
# # 14. Handling Categorical Data:
# Question: For categorical indicators, consider encoding or transforming them into a format suitable for analysis.

# %% [markdown]
# # Label Encoding for Easy Apply Column

# %%
# Mapping 'True' to 1 and 'False' to 0 in the 'Easy Apply' column
df['Easy Apply'] = df['Easy Apply'].map({True: 1, False: 0}).astype(int)
# Out:
# C:\Users\91638\AppData\Local\Temp\ipykernel_264\2778718712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Easy Apply'] = df['Easy Apply'].map({True: 1, False: 0}).astype(int)

# %%
df.head(10)
# Out:
#    Age  Rating   Location  Established  Easy Apply  Average Salary  \
# 0   44     5.0      India         1999           1         71500.0
# 1   62     3.5   New York         2002           1         60500.0
# 2   39     0.0   New York         1955           0         83000.0
# 3   62     4.4      India         1988           0         71500.0
# 4   25     5.0  Australia         2002           0         71500.0
# 5   44     1.4      India         1999           1         83000.0
# 6   21     0.0   New York         1955           0         71500.0
# 7   44     0.0  Australia         2000           0         71500.0
# 8   35     5.0   New York         1955           0         71500.0
# 9   22     5.0      India         1999           1         71500.0
#
#    Expected_Age
# 0            24
# 1            21
# 2            68
# 3            35
# 4            21
# 5            24
# 6            68
# 7            23
# 8            68
# 9            24

# %% [markdown]
# # One Hot Encoding -using dummies(for Location Column)

# %%
encoded_df=pd.get_dummies(df,prefix=['Location'],columns=['Location'])
df=encoded_df
df
# Out:
#     Age  Rating  Established  Easy Apply  Average Salary  Expected_Age  \
# 0    44     5.0         1999           1         71500.0            24
# 1    62     3.5         2002           1         60500.0            21
# 2    39     0.0         1955           0         83000.0            68
# 3    62     4.4         1988           0         71500.0            35
# 4    25     5.0         2002           0         71500.0            21
# 5    44     1.4         1999           1         83000.0            24
# 6    21     0.0         1955           0         71500.0            68
# 7    44     0.0         2000           0         71500.0            23
# 8    35     5.0         1955           0         71500.0            68
# 9    22     5.0         1999           1         71500.0            24
# 10   55     5.0         2008           1         29500.0            15
# 11   44     5.0         2009           0         29500.0            14
# 12   39     0.0         1999           0         71500.0            24
# 13   25     0.0         2019           1         71500.0             4
# 14   62     4.0         2020           1         71500.0             3
# 15   44     3.0         1999           0         94500.0            24
# 16   19     4.5         1984           0         29500.0            39
# 17   39     5.0         1943           1         71500.0            80
# 18   35     5.0         1954           1         71500.0            69
# 19   32     3.3         1955           1         71500.0            68
# 20   39     5.0         1944           1         71500.0            79
# 21   35     5.0         1946           0         71500.0            77
# 22   19     5.0         1988           1         60500.0            35
# 23   39     2.4         1999           1         71500.0            24
# 25   55     0.0         1980           1         71500.0            43
# 26   39     0.0         1934           1         60500.0            89
# 27   52     5.0         1935           0         71500.0            88
# 28   39     3.4         1932           0         63500.0            91
#
#     Location_Australia  Location_India  Location_New York
# 0                    0               1                  0
# 1                    0               0                  1
# 2                    0               0                  1
# 3                    0               1                  0
# 4                    1               0                  0
# 5                    0               1                  0
# 6                    0               0                  1
# 7                    1               0                  0
# 8                    0               0                  1
# 9                    0               1                  0
# 10                   0               1                  0
# 11                   0               1                  0
# 12                   0               1                  0
# 13                   1               0                  0
# 14                   1               0                  0
# 15                   1               0                  0
# 16                   0               1                  0
# 17                   0               0                  1
# 18                   0               0                  1
# 19                   0               0                  1
# 20                   0               0                  1
# 21                   0               0                  1
# 22                   0               0                  1
# 23                   0               0                  1
# 25                   1               0                  0
# 26                   0               1                  0
# 27                   0               1                  0
# 28                   1               0                  0

# %% [markdown]
# # 15. Consistent Rating Scale:
# Question: Ensure a consistent rating scale in the Rating column. Should it be normalized or adjusted for uniform analysis?

# %%
# Min-max scaling to normalize the 'Rating' column between 0 and 1
df['Normalized Rating'] = (df['Rating'] - df['Rating'].min()) / (df['Rating'].max() - df['Rating'].min())
df['Normalized Rating']
# Out:
# 0     1.00
# 1     0.70
# 2     0.00
# 3     0.88
# 4     1.00
# 5     0.28
# 6     0.00
# 7     0.00
# 8     1.00
# 9     1.00
# 10    1.00
# 11    1.00
# 12    0.00
# 13    0.00
# 14    0.80
# 15    0.60
# 16    0.90
# 17    1.00
# 18    1.00
# 19    0.66
# 20    1.00
# 21    1.00
# 22    1.00
# 23    0.48
# 25    0.00
# 26    0.00
# 27    1.00
# 28    0.68
# Name: Normalized Rating, dtype: float64

# %%
df.head(8)
# Out:
#    Age  Rating  Established  Easy Apply  Average Salary  Expected_Age  \
# 0   44     5.0         1999           1         71500.0            24
# 1   62     3.5         2002           1         60500.0            21
# 2   39     0.0         1955           0         83000.0            68
# 3   62     4.4         1988           0         71500.0            35
# 4   25     5.0         2002           0         71500.0            21
# 5   44     1.4         1999           1         83000.0            24
# 6   21     0.0         1955           0         71500.0            68
# 7   44     0.0         2000           0         71500.0            23
#
#    Location_Australia  Location_India  Location_New York  Normalized Rating
# 0                   0               1                  0               1.00
# 1                   0               0                  1               0.70
# 2                   0               0                  1               0.00
# 3                   0               1                  0               0.88
# 4                   1               0                  0               1.00
# 5                   0               1                  0               0.28
# 6                   0               0                  1               0.00
# 7                   1               0                  0               0.00

# %%
df
# Out:
#     Age  Rating  Established  Easy Apply  Average Salary  Expected_Age  \
# 0    44     5.0         1999           1         71500.0            24
# 1    62     3.5         2002           1         60500.0            21
# 2    39     0.0         1955           0         83000.0            68
# 3    62     4.4         1988           0         71500.0            35
# 4    25     5.0         2002           0         71500.0            21
# 5    44     1.4         1999           1         83000.0            24
# 6    21     0.0         1955           0         71500.0            68
# 7    44     0.0         2000           0         71500.0            23
# 8    35     5.0         1955           0         71500.0            68
# 9    22     5.0         1999           1         71500.0            24
# 10   55     5.0         2008           1         29500.0            15
# 11   44     5.0         2009           0         29500.0            14
# 12   39     0.0         1999           0         71500.0            24
# 13   25     0.0         2019           1         71500.0             4
# 14   62     4.0         2020           1         71500.0             3
# 15   44     3.0         1999           0         94500.0            24
# 16   19     4.5         1984           0         29500.0            39
# 17   39     5.0         1943           1         71500.0            80
# 18   35     5.0         1954           1         71500.0            69
# 19   32     3.3         1955           1         71500.0            68
# 20   39     5.0         1944           1         71500.0            79
# 21   35     5.0         1946           0         71500.0            77
# 22   19     5.0         1988           1         60500.0            35
# 23   39     2.4         1999           1         71500.0            24
# 25   55     0.0         1980           1         71500.0            43
# 26   39     0.0         1934           1         60500.0            89
# 27   52     5.0         1935           0         71500.0            88
# 28   39     3.4         1932           0         63500.0            91
#
#     Location_Australia  Location_India  Location_New York  Normalized Rating
# 0                    0               1                  0               1.00
# 1                    0               0                  1               0.70
# 2                    0               0                  1               0.00
# 3                    0               1                  0               0.88
# 4                    1               0                  0               1.00
# 5                    0               1                  0               0.28
# 6                    0               0                  1               0.00
# 7                    1               0                  0               0.00
# 8                    0               0                  1               1.00
# 9                    0               1                  0               1.00
# 10                   0               1                  0               1.00
# 11                   0               1                  0               1.00
# 12                   0               1                  0               0.00
# 13                   1               0                  0               0.00
# 14                   1               0                  0               0.80
# 15                   1               0                  0               0.60
# 16                   0               1                  0               0.90
# 17                   0               0                  1               1.00
# 18                   0               0                  1               1.00
# 19                   0               0                  1               0.66
# 20                   0               0                  1               1.00
# 21                   0               0                  1               1.00
# 22                   0               0                  1               1.00
# 23                   0               0                  1               0.48
# 25                   1               0                  0               0.00
# 26                   0               1                  0               0.00
# 27                   0               1                  0               1.00
# 28                   1               0                  0               0.68

# %%
# converting to CSV file
df.to_csv("Week3_Cleaned_Data.csv", encoding = 'utf-8',index=False)

# %%
cleant_data=pd.read_csv("Week3_Cleaned_Data.csv")
cleant_data
# Out:
#     Age  Rating  Established  Easy Apply  Average Salary  Expected_Age  \
# 0    44     5.0         1999           1         71500.0            24
# 1    62     3.5         2002           1         60500.0            21
# 2    39     0.0         1955           0         83000.0            68
# 3    62     4.4         1988           0         71500.0            35
# 4    25     5.0         2002           0         71500.0            21
# 5    44     1.4         1999           1         83000.0            24
# 6    21     0.0         1955           0         71500.0            68
# 7    44     0.0         2000           0         71500.0            23
# 8    35     5.0         1955           0         71500.0            68
# 9    22     5.0         1999           1         71500.0            24
# 10   55     5.0         2008           1         29500.0            15
# 11   44     5.0         2009           0         29500.0            14
# 12   39     0.0         1999           0         71500.0            24
# 13   25     0.0         2019           1         71500.0             4
# 14   62     4.0         2020           1         71500.0             3
# 15   44     3.0         1999           0         94500.0            24
# 16   19     4.5         1984           0         29500.0            39
# 17   39     5.0         1943           1         71500.0            80
# 18   35     5.0         1954           1         71500.0            69
# 19   32     3.3         1955           1         71500.0            68
# 20   39     5.0         1944           1         71500.0            79
# 21   35     5.0         1946           0         71500.0            77
# 22   19     5.0         1988           1         60500.0            35
# 23   39     2.4         1999           1         71500.0            24
# 24   55     0.0         1980           1         71500.0            43
# 25   39     0.0         1934           1         60500.0            89
# 26   52     5.0         1935           0         71500.0            88
# 27   39     3.4         1932           0         63500.0            91
#
#     Location_Australia  Location_India  Location_New York  Normalized Rating
# 0                    0               1                  0               1.00
# 1                    0               0                  1               0.70
# 2                    0               0                  1               0.00
# 3                    0               1                  0               0.88
# 4                    1               0                  0               1.00
# 5                    0               1                  0               0.28
# 6                    0               0                  1               0.00
# 7                    1               0                  0               0.00
# 8                    0               0                  1               1.00
# 9                    0               1                  0               1.00
# 10                   0               1                  0               1.00
# 11                   0               1                  0               1.00
# 12                   0               1                  0               0.00
# 13                   1               0                  0               0.00
# 14                   1               0                  0               0.80
# 15                   1               0                  0               0.60
# 16                   0               1                  0               0.90
# 17                   0               0                  1               1.00
# 18                   0               0                  1               1.00
# 19                   0               0                  1               0.66
# 20                   0               0                  1               1.00
# 21                   0               0                  1               1.00
# 22                   0               0                  1               1.00
# 23                   0               0                  1               0.48
# 24                   1               0                  0               0.00
# 25                   0               1                  0               0.00
# 26                   0               1                  0               1.00
# 27                   1               0                  0               0.68
